# %%
import pandas as pd

# %%
Full_Istituzioni_link = "Full_Istituzioni.csv"
Full_Istituzioni = pd.read_csv(Full_Istituzioni_link)
Full_Istituzioni
# Out:
#              Istituzione             Direzione  \
# 0    Parlamento Italiano   Camera dei Deputati
# 1    Parlamento Italiano   Camera dei Deputati
# 2    Parlamento Italiano   Camera dei Deputati
# 3    Parlamento Italiano   Camera dei Deputati
# 4    Parlamento Italiano   Camera dei Deputati
# ..                   ...                   ...
# 702                Altro  Universit├á Italiane
# 703                Altro  Universit├á Italiane
# 704                Altro  Universit├á Italiane
# 705                Altro  Universit├á Italiane
# 706                Altro  Universit├á Italiane
#
#                                            Ufficio               Riferimento  \
# 0    Commissione Permanente Giustizia della Camera              MASCHIO Ciro
# 1    Commissione Permanente Giustizia della Camera  CAFIERO DE RAHO Federico
# 2    Commissione Permanente Giustizia della Camera           PITTALIS Pietro
# 3    Commissione Permanente Giustizia della Camera            MORRONE Jacopo
# 4    Commissione Permanente Giustizia della Camera            ZAN Alessandro
# ..                                             ...                       ...
# 702                  Rettore L'Orientale di Napoli           Tottoli Roberto
# 703               Rettore Universit├á della Tuscia          Ubertini Stefano
# 704      Rettore Universit├á Carlo Cattaneo - LIUC         Visconti Federico
# 705                     Rettore di Reggio Calabria       Zimbalatti Giuseppe
# 706                    Rettore Universit├á di Pisa           Zucchi Riccardo
#
#                                                Partito  \
# 0                                    FRATELLI D'ITALIA
# 1                                   MOVIMENTO 5 STELLE
# 2           FORZA ITALIA - BERLUSCONI PRESIDENTE - PPE
# 3                               LEGA - SALVINI PREMIER
# 4    PARTITO DEMOCRATICO - ITALIA DEMOCRATICA E PRO...
# ..                                                 ...
# 702                                                NaN
# 703                                                NaN
# 704                                                NaN
# 705                                                NaN
# 706                                                NaN
#
#                                                   Foto
# 0    https://documenti.camera.it/_dati/leg19/schede...
# 1    https://documenti.camera.it/_dati/leg19/schede...
# 2    https://documenti.camera.it/_dati/leg19/schede...
# 3    https://documenti.camera.it/_dati/leg19/schede...
# 4    https://documenti.camera.it/_dati/leg19/schede...
# ..                                                 ...
# 702  https://www.crui.it/media/k2/items/cache/c6d32...
# 703  https://www.crui.it/media/k2/items/cache/da0a8...
# 704  https://www.crui.it/media/k2/items/cache/42a35...
# 705  https://www.crui.it/media/k2/items/cache/fbb7f...
# 706  https://www.crui.it/media/k2/items/cache/980e6...
#
# [707 rows x 6 columns]

# %%
import random

# %%
# Definisco il numero totale di record da selezionare
total_records = 496

# %%
# Definisco le percentuali di incontro per istituzione
percentages = {
    'Private': 0.05,
    'Parlamento Europeo': 0.15,
    'Altro': 0.10,
    'Parlamento Italiano': 0.45,
    'Governo Italiano': 0.25
}

# %%
# Calcol0 il numero di record da selezionare per ogni istituzione
num_records = {key: int(total_records * percentage) for key, percentage in percentages.items()}

# %%
sampled_records = []

# %%
# Imposto la scelta randomica dei record per ogni istituzione
for istituzione, count in num_records.items():
    subset = Full_Istituzioni[Full_Istituzioni['Istituzione'] == istituzione]
    sampled_records.extend(random.choices(subset.to_dict('records'), k=count))

# %%
sampled_df = pd.DataFrame(sampled_records)

# %%
sampled_df.drop('Partito', axis=1, inplace=True)
sampled_df.drop('Foto', axis=1, inplace=True)

# %%
sampled_df
# Out:
#           Istituzione                                          Direzione  \
# 0             Private     Vendita al dettaglio all'ingrosso & E-commerce
# 1             Private         Energia Approvvigionamento & Materie prime
# 2             Private                                  Telecomunicazioni
# 3             Private                               Alimentari & Bevande
# 4             Private                                               Moda
# ..                ...                                                ...
# 489  Governo Italiano     Ministero del Lavoro e delle Politiche Sociali
# 490  Governo Italiano  Ministero per la famiglia la natalit├á e le pa...
# 491  Governo Italiano  Ministero degli Affari esteri e della cooperaz...
# 492  Governo Italiano                              Ministero del Turismo
# 493  Governo Italiano  Ministero per la famiglia la natalit├á e le pa...
#
#                                                Ufficio  \
# 0                                       Aspiag Service
# 1                                                  ERG
# 2                                           Gruppo TIM
# 3                            Andriani Societ├á Benefit
# 4                                                  OVS
# ..                                                 ...
# 489                         Lavoro e politiche sociali
# 490  Ministro senza portafoglio per la famiglia la ...
# 491                     Affari esteri e coop. inter.le
# 492                                            Turismo
# 493  Ministro senza portafoglio per la famiglia la ...
#
#                     Riferimento
# 0               Alberto Moretti
# 1                Ludovica Gatti
# 2                 Rocco Ferrari
# 3                  Miriam Rizzi
# 4             Valentina De Rosa
# ..                          ...
# 489     CALDERONE Marina Elvira
# 490      ROCCELLA Eugenia Maria
# 491              TAJANI Antonio
# 492  GARNERO SANTANCHE' Daniela
# 493      ROCCELLA Eugenia Maria
#
# [494 rows x 4 columns]

# %%
# Funzione per verificare se una data è una festività italiana
def is_holiday(date):
    italian_holidays = [
        (1, 1),    # Capodanno
        (1, 6),    # Epifania
        (4, 25),   # Festa della Liberazione
        (5, 1),    # Festa dei Lavoratori
        (6, 2),    # Festa della Repubblica
        (8, 15),   # Assunzione di Maria
        (11, 1),   # Ognissanti
        (12, 8),   # Immacolata Concezione
        (12, 25),  # Natale
        (12, 26)   # Santo Stefano
    ]
    if (date.month, date.day) in italian_holidays:
        return True
    if date.weekday() == 6:  # Domenica
        return True
    return False

# %%
# Funzione per generare una data randomica dal 01/01/2022 ad oggi, escludendo i giorni festivi
def generate_random_date():
    start_date = datetime(2022, 1, 1)
    end_date = datetime.today()
    while True:
        random_days = random.randint(0, (end_date - start_date).days)
        random_date = start_date + timedelta(days=random_days)
        if not is_holiday(random_date):
            return random_date

# %%
from datetime import datetime, timedelta

# %%
# Aggiungo la colonna 'Data_Incontro' con date randomiche valide
sampled_df['Data_Incontro'] = [generate_random_date() for _ in range(len(sampled_df))]

# %%
sampled_df
# Out:
#           Istituzione                                          Direzione  \
# 0             Private     Vendita al dettaglio all'ingrosso & E-commerce
# 1             Private         Energia Approvvigionamento & Materie prime
# 2             Private                                  Telecomunicazioni
# 3             Private                               Alimentari & Bevande
# 4             Private                                               Moda
# ..                ...                                                ...
# 489  Governo Italiano     Ministero del Lavoro e delle Politiche Sociali
# 490  Governo Italiano  Ministero per la famiglia la natalit├á e le pa...
# 491  Governo Italiano  Ministero degli Affari esteri e della cooperaz...
# 492  Governo Italiano                              Ministero del Turismo
# 493  Governo Italiano  Ministero per la famiglia la natalit├á e le pa...
#
#                                                Ufficio  \
# 0                                       Aspiag Service
# 1                                                  ERG
# 2                                           Gruppo TIM
# 3                            Andriani Societ├á Benefit
# 4                                                  OVS
# ..                                                 ...
# 489                         Lavoro e politiche sociali
# 490  Ministro senza portafoglio per la famiglia la ...
# 491                     Affari esteri e coop. inter.le
# 492                                            Turismo
# 493  Ministro senza portafoglio per la famiglia la ...
#
#                     Riferimento Data_Incontro
# 0               Alberto Moretti    2023-10-10
# 1                Ludovica Gatti    2022-02-19
# 2                 Rocco Ferrari    2024-02-20
# 3                  Miriam Rizzi    2022-01-27
# 4             Valentina De Rosa    2024-04-13
# ..                          ...           ...
# 489     CALDERONE Marina Elvira    2022-08-27
# 490      ROCCELLA Eugenia Maria    2022-11-04
# 491              TAJANI Antonio    2022-10-27
# 492  GARNERO SANTANCHE' Daniela    2024-02-14
# 493      ROCCELLA Eugenia Maria    2022-09-30
#
# [494 rows x 5 columns]

# %%
sampled_df = sampled_df.sort_values(by='Data_Incontro')

# %%
sampled_df
# Out:
#              Istituzione                                          Direzione  \
# 227  Parlamento Italiano                            Senato della Repubblica
# 298  Parlamento Italiano                                Camera dei Deputati
# 195  Parlamento Italiano                                Camera dei Deputati
# 167  Parlamento Italiano                            Senato della Repubblica
# 406     Governo Italiano  Ministero per la famiglia la natalit├á e le pa...
# ..                   ...                                                ...
# 210  Parlamento Italiano                            Senato della Repubblica
# 267  Parlamento Italiano                                Camera dei Deputati
# 62    Parlamento Europeo                               Parlamentare Europeo
# 154  Parlamento Italiano                                Camera dei Deputati
# 174  Parlamento Italiano                                Camera dei Deputati
#
#                                                Ufficio  \
# 227                             Affari esteri e difesa
# 298                      Politiche Dell'Unione Europea
# 195         Commissione Permanente Difesa della Camera
# 167                             Affari esteri e difesa
# 406  Ministro senza portafoglio per la famiglia la ...
# ..                                                 ...
# 210                      Politiche dell'Unione europea
# 267              Ambiente Territorio E Lavori Pubblici
# 62                                              Italia
# 154                         Affari Esteri E Comunitari
# 174                          Lavoro Pubblico E Privato
#
#                   Riferimento Data_Incontro
# 227           SPAGNOLLI Luigi    2022-01-07
# 298   GIGLIO VIGNA Alessandro    2022-01-11
# 195             FASSINO Piero    2022-01-12
# 167    CASINI Pier Ferdinando    2022-01-14
# 406    ROCCELLA Eugenia Maria    2022-01-19
# ..                        ...           ...
# 210              RENZI Matteo    2024-05-06
# 267            L'ABBATE Patty    2024-05-07
# 62         Alessandra MORETTI    2024-05-08
# 154  QUARTAPELLE PROCOPIO Lia    2024-05-11
# 174           GIACCONE Andrea    2024-05-16
#
# [494 rows x 5 columns]

# %%
# Scelta randomica per modalità di incontro
sampled_df['Modalita_Incontro'] = [random.choice(['Online', 'De Visu']) for _ in range(len(sampled_df))]

# %%
sampled_df
# Out:
#              Istituzione                                          Direzione  \
# 227  Parlamento Italiano                            Senato della Repubblica
# 298  Parlamento Italiano                                Camera dei Deputati
# 195  Parlamento Italiano                                Camera dei Deputati
# 167  Parlamento Italiano                            Senato della Repubblica
# 406     Governo Italiano  Ministero per la famiglia la natalit├á e le pa...
# ..                   ...                                                ...
# 210  Parlamento Italiano                            Senato della Repubblica
# 267  Parlamento Italiano                                Camera dei Deputati
# 62    Parlamento Europeo                               Parlamentare Europeo
# 154  Parlamento Italiano                                Camera dei Deputati
# 174  Parlamento Italiano                                Camera dei Deputati
#
#                                                Ufficio  \
# 227                             Affari esteri e difesa
# 298                      Politiche Dell'Unione Europea
# 195         Commissione Permanente Difesa della Camera
# 167                             Affari esteri e difesa
# 406  Ministro senza portafoglio per la famiglia la ...
# ..                                                 ...
# 210                      Politiche dell'Unione europea
# 267              Ambiente Territorio E Lavori Pubblici
# 62                                              Italia
# 154                         Affari Esteri E Comunitari
# 174                          Lavoro Pubblico E Privato
#
#                   Riferimento Data_Incontro Modalita_Incontro
# 227           SPAGNOLLI Luigi    2022-01-07            Online
# 298   GIGLIO VIGNA Alessandro    2022-01-11            Online
# 195             FASSINO Piero    2022-01-12            Online
# 167    CASINI Pier Ferdinando    2022-01-14           De Visu
# 406    ROCCELLA Eugenia Maria    2022-01-19            Online
# ..                        ...           ...               ...
# 210              RENZI Matteo    2024-05-06            Online
# 267            L'ABBATE Patty    2024-05-07           De Visu
# 62         Alessandra MORETTI    2024-05-08            Online
# 154  QUARTAPELLE PROCOPIO Lia    2024-05-11           De Visu
# 174           GIACCONE Andrea    2024-05-16           De Visu
#
# [494 rows x 6 columns]

# %%
#Predispongo la colonna INFO per inserimenti futuri
sampled_df['Info'] = None
sampled_df
# Out:
#              Istituzione                                          Direzione  \
# 227  Parlamento Italiano                            Senato della Repubblica
# 298  Parlamento Italiano                                Camera dei Deputati
# 195  Parlamento Italiano                                Camera dei Deputati
# 167  Parlamento Italiano                            Senato della Repubblica
# 406     Governo Italiano  Ministero per la famiglia la natalit├á e le pa...
# ..                   ...                                                ...
# 210  Parlamento Italiano                            Senato della Repubblica
# 267  Parlamento Italiano                                Camera dei Deputati
# 62    Parlamento Europeo                               Parlamentare Europeo
# 154  Parlamento Italiano                                Camera dei Deputati
# 174  Parlamento Italiano                                Camera dei Deputati
#
#                                                Ufficio  \
# 227                             Affari esteri e difesa
# 298                      Politiche Dell'Unione Europea
# 195         Commissione Permanente Difesa della Camera
# 167                             Affari esteri e difesa
# 406  Ministro senza portafoglio per la famiglia la ...
# ..                                                 ...
# 210                      Politiche dell'Unione europea
# 267              Ambiente Territorio E Lavori Pubblici
# 62                                              Italia
# 154                         Affari Esteri E Comunitari
# 174                          Lavoro Pubblico E Privato
#
#                   Riferimento Data_Incontro Modalita_Incontro  Info
# 227           SPAGNOLLI Luigi    2022-01-07            Online  None
# 298   GIGLIO VIGNA Alessandro    2022-01-11            Online  None
# 195             FASSINO Piero    2022-01-12            Online  None
# 167    CASINI Pier Ferdinando    2022-01-14           De Visu  None
# 406    ROCCELLA Eugenia Maria    2022-01-19            Online  None
# ..                        ...           ...               ...   ...
# 210              RENZI Matteo    2024-05-06            Online  None
# 267            L'ABBATE Patty    2024-05-07           De Visu  None
# 62         Alessandra MORETTI    2024-05-08            Online  None
# 154  QUARTAPELLE PROCOPIO Lia    2024-05-11           De Visu  None
# 174           GIACCONE Andrea    2024-05-16           De Visu  None
#
# [494 rows x 7 columns]

# %%
# Definisco i pesi per ogni valore di 'Id_Valutazione'
valutazione_choices = [1, 2, 3, 4, 5]
valutazione_weights = [0.03, 0.22, 0.40, 0.30, 0.05]

# %%
sampled_df['Id_Valutazione'] = random.choices(valutazione_choices, weights=valutazione_weights, k=len(sampled_df))
sampled_df
# Out:
#              Istituzione                                          Direzione  \
# 227  Parlamento Italiano                            Senato della Repubblica
# 298  Parlamento Italiano                                Camera dei Deputati
# 195  Parlamento Italiano                                Camera dei Deputati
# 167  Parlamento Italiano                            Senato della Repubblica
# 406     Governo Italiano  Ministero per la famiglia la natalit├á e le pa...
# ..                   ...                                                ...
# 210  Parlamento Italiano                            Senato della Repubblica
# 267  Parlamento Italiano                                Camera dei Deputati
# 62    Parlamento Europeo                               Parlamentare Europeo
# 154  Parlamento Italiano                                Camera dei Deputati
# 174  Parlamento Italiano                                Camera dei Deputati
#
#                                                Ufficio  \
# 227                             Affari esteri e difesa
# 298                      Politiche Dell'Unione Europea
# 195         Commissione Permanente Difesa della Camera
# 167                             Affari esteri e difesa
# 406  Ministro senza portafoglio per la famiglia la ...
# ..                                                 ...
# 210                      Politiche dell'Unione europea
# 267              Ambiente Territorio E Lavori Pubblici
# 62                                              Italia
# 154                         Affari Esteri E Comunitari
# 174                          Lavoro Pubblico E Privato
#
#                   Riferimento Data_Incontro Modalita_Incontro  Info  \
# 227           SPAGNOLLI Luigi    2022-01-07            Online  None
# 298   GIGLIO VIGNA Alessandro    2022-01-11            Online  None
# 195             FASSINO Piero    2022-01-12            Online  None
# 167    CASINI Pier Ferdinando    2022-01-14           De Visu  None
# 406    ROCCELLA Eugenia Maria    2022-01-19            Online  None
# ..                        ...           ...               ...   ...
# 210              RENZI Matteo    2024-05-06            Online  None
# 267            L'ABBATE Patty    2024-05-07           De Visu  None
# 62         Alessandra MORETTI    2024-05-08            Online  None
# 154  QUARTAPELLE PROCOPIO Lia    2024-05-11           De Visu  None
# 174           GIACCONE Andrea    2024-05-16           De Visu  None
#
#      Id_Valutazione
# 227               3
# 298               3
# 195               1
# 167               2
# 406               2
# ..              ...
# 210               4
# 267               4
# 62                3
# 154               2
# 174               3
#
# [494 rows x 8 columns]

# %%
#Creo ID_Incontro
sampled_df['ID_Incontro'] = range(1, len(sampled_df) + 1)
sampled_df
# Out:
#              Istituzione                                          Direzione  \
# 227  Parlamento Italiano                            Senato della Repubblica
# 298  Parlamento Italiano                                Camera dei Deputati
# 195  Parlamento Italiano                                Camera dei Deputati
# 167  Parlamento Italiano                            Senato della Repubblica
# 406     Governo Italiano  Ministero per la famiglia la natalit├á e le pa...
# ..                   ...                                                ...
# 210  Parlamento Italiano                            Senato della Repubblica
# 267  Parlamento Italiano                                Camera dei Deputati
# 62    Parlamento Europeo                               Parlamentare Europeo
# 154  Parlamento Italiano                                Camera dei Deputati
# 174  Parlamento Italiano                                Camera dei Deputati
#
#                                                Ufficio  \
# 227                             Affari esteri e difesa
# 298                      Politiche Dell'Unione Europea
# 195         Commissione Permanente Difesa della Camera
# 167                             Affari esteri e difesa
# 406  Ministro senza portafoglio per la famiglia la ...
# ..                                                 ...
# 210                      Politiche dell'Unione europea
# 267              Ambiente Territorio E Lavori Pubblici
# 62                                              Italia
# 154                         Affari Esteri E Comunitari
# 174                          Lavoro Pubblico E Privato
#
#                   Riferimento Data_Incontro Modalita_Incontro  Info  \
# 227           SPAGNOLLI Luigi    2022-01-07            Online  None
# 298   GIGLIO VIGNA Alessandro    2022-01-11            Online  None
# 195             FASSINO Piero    2022-01-12            Online  None
# 167    CASINI Pier Ferdinando    2022-01-14           De Visu  None
# 406    ROCCELLA Eugenia Maria    2022-01-19            Online  None
# ..                        ...           ...               ...   ...
# 210              RENZI Matteo    2024-05-06            Online  None
# 267            L'ABBATE Patty    2024-05-07           De Visu  None
# 62         Alessandra MORETTI    2024-05-08            Online  None
# 154  QUARTAPELLE PROCOPIO Lia    2024-05-11           De Visu  None
# 174           GIACCONE Andrea    2024-05-16           De Visu  None
#
#      Id_Valutazione  ID_Incontro
# 227               3            1
# 298               3            2
# 195               1            3
# 167               2            4
# 406               2            5
# ..              ...          ...
# 210               4          490
# 267               4          491
# 62                3          492
# 154               2          493
# 174               3          494
#
# [494 rows x 9 columns]

# %%
#Importo il file Anagrafiche, mantengo i record per Ruolo = Dipendente ed elimino le colonne non utili
Anagrafiche_link = "anagrafiche.csv"
Anagrafiche = pd.read_csv(Anagrafiche_link)

# %%
Anagrafiche.drop('Data di Nascita', axis=1, inplace=True)
Anagrafiche.drop('Sesso', axis=1, inplace=True)
Anagrafiche.drop('Codice Fiscale', axis=1, inplace=True)
Anagrafiche.drop('Mail', axis=1, inplace=True)
Anagrafiche.drop('LoginID', axis=1, inplace=True)
Anagrafiche
# Out:
#           Nome    Cognome       Ruolo             Dipartimento  \
# 0      Arianna  Valentini   Direttore       Advocacy Nazionale
# 1      Massimo      Amato   Direttore  Advocacy Internazionale
# 2     Federico      Bruno  Dipendente       Advocacy Nazionale
# 3      Arianna  Marchetti  Dipendente  Advocacy Internazionale
# 4       Sergio    Rinaldi  Dipendente       Advocacy Nazionale
# ..         ...        ...         ...                      ...
# 102     Andrea    Colombo  Dipendente       Advocacy Nazionale
# 103     Sergio      Rizzo  Dipendente       Advocacy Nazionale
# 104   Federica  Salvatore  Dipendente  Advocacy Internazionale
# 105      Greta      Testa  Dipendente  Advocacy Internazionale
# 106  Salvatore      Monti  Dipendente       Advocacy Nazionale
#
#                          Area  \
# 0                         NaN
# 1                         NaN
# 2                  Educazione
# 3                     Private
# 4    Migrazione & Accoglienza
# ..                        ...
# 102                   Povertà
# 103                    Salute
# 104          Crisi Umanitarie
# 105          Crisi Umanitarie
# 106                   Povertà
#
#                                             Tematica Data Assunzione  \
# 0                                                NaN      2018-01-01
# 1                                                NaN      2018-01-01
# 2                             Dispersione Scolastica      2020-12-17
# 3                                        Agenda 2030      2018-04-17
# 4                                         Inclusione      2019-05-20
# ..                                               ...             ...
# 102               Reddito di Inclusione/Cittadinanza      2019-01-15
# 103  Supporto a Minori Vittime di Violenza Assistita      2021-01-22
# 104                                             Armi      2018-06-02
# 105                                 Aree Geografiche      2020-02-26
# 106         Supporto a Famiglie Vittime di Emergenze      2023-09-15
#
#     Data Fine Rapporto    Data Inizio Ruolo Data Fine Ruolo Stato Ruolo
# 0                  NaN  2018-01-01 00:00:00             NaN      Attivo
# 1                  NaN  2018-01-01 00:00:00             NaN      Attivo
# 2                  NaN  2020-12-17 00:00:00             NaN      Attivo
# 3                  NaN  2018-04-17 00:00:00             NaN      Attivo
# 4                  NaN  2019-05-20 00:00:00             NaN      Attivo
# ..                 ...                  ...             ...         ...
# 102                NaN           2021/04/25             NaN      Attivo
# 103                NaN           2021/09/20             NaN      Attivo
# 104                NaN           2019/09/18             NaN      Attivo
# 105                NaN           2021/07/19             NaN      Attivo
# 106                NaN           2023/10/09             NaN      Attivo
#
# [107 rows x 11 columns]

# %%
Anagrafiche = Anagrafiche[Anagrafiche['Ruolo'] != 'Direttore']
Anagrafiche
# Out:
#           Nome    Cognome       Ruolo             Dipartimento  \
# 2     Federico      Bruno  Dipendente       Advocacy Nazionale
# 3      Arianna  Marchetti  Dipendente  Advocacy Internazionale
# 4       Sergio    Rinaldi  Dipendente       Advocacy Nazionale
# 5         Luna      Messi  Dipendente  Advocacy Internazionale
# 6    Francesco      Rizzo  Dipendente       Advocacy Nazionale
# ..         ...        ...         ...                      ...
# 102     Andrea    Colombo  Dipendente       Advocacy Nazionale
# 103     Sergio      Rizzo  Dipendente       Advocacy Nazionale
# 104   Federica  Salvatore  Dipendente  Advocacy Internazionale
# 105      Greta      Testa  Dipendente  Advocacy Internazionale
# 106  Salvatore      Monti  Dipendente       Advocacy Nazionale
#
#                          Area  \
# 2                  Educazione
# 3                     Private
# 4    Migrazione & Accoglienza
# 5                       Clima
# 6                     Povertà
# ..                        ...
# 102                   Povertà
# 103                    Salute
# 104          Crisi Umanitarie
# 105          Crisi Umanitarie
# 106                   Povertà
#
#                                             Tematica Data Assunzione  \
# 2                             Dispersione Scolastica      2020-12-17
# 3                                        Agenda 2030      2018-04-17
# 4                                         Inclusione      2019-05-20
# 5                                    Generation Hope      2024-12-17
# 6           Supporto a Famiglie Vittime di Emergenze      2018-04-15
# ..                                               ...             ...
# 102               Reddito di Inclusione/Cittadinanza      2019-01-15
# 103  Supporto a Minori Vittime di Violenza Assistita      2021-01-22
# 104                                             Armi      2018-06-02
# 105                                 Aree Geografiche      2020-02-26
# 106         Supporto a Famiglie Vittime di Emergenze      2023-09-15
#
#     Data Fine Rapporto    Data Inizio Ruolo Data Fine Ruolo Stato Ruolo
# 2                  NaN  2020-12-17 00:00:00             NaN      Attivo
# 3                  NaN  2018-04-17 00:00:00             NaN      Attivo
# 4                  NaN  2019-05-20 00:00:00             NaN      Attivo
# 5                  NaN  2024-12-17 00:00:00             NaN      Attivo
# 6                  NaN  2018-04-15 00:00:00             NaN      Attivo
# ..                 ...                  ...             ...         ...
# 102                NaN           2021/04/25             NaN      Attivo
# 103                NaN           2021/09/20             NaN      Attivo
# 104                NaN           2019/09/18             NaN      Attivo
# 105                NaN           2021/07/19             NaN      Attivo
# 106                NaN           2023/10/09             NaN      Attivo
#
# [105 rows x 11 columns]

# %%
Anagrafiche.drop('Data Assunzione', axis=1, inplace=True)
Anagrafiche.drop('Data Fine Rapporto', axis=1, inplace=True)
Anagrafiche.drop('Stato Ruolo', axis=1, inplace=True)
Anagrafiche
# Out:
# C:\Users\spetr\AppData\Local\Temp\ipykernel_13700\3421187431.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Anagrafiche.drop('Data Assunzione', axis=1, inplace=True)
# C:\Users\spetr\AppData\Local\Temp\ipykernel_13700\3421187431.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Anagrafiche.drop('Data Fine Rapporto', axis=1, inplace=True)
# C:\Users\spetr\AppData\Local\Temp\ipykernel_13700\3421187431.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Anagrafiche.drop('Stato Ruolo', axis=1, inplace=True)
#           Nome    Cognome       Ruolo             Dipartimento  \
# 2     Federico      Bruno  Dipendente       Advocacy Nazionale
# 3      Arianna  Marchetti  Dipendente  Advocacy Internazionale
# 4       Sergio    Rinaldi  Dipendente       Advocacy Nazionale
# 5         Luna      Messi  Dipendente  Advocacy Internazionale
# 6    Francesco      Rizzo  Dipendente       Advocacy Nazionale
# ..         ...        ...         ...                      ...
# 102     Andrea    Colombo  Dipendente       Advocacy Nazionale
# 103     Sergio      Rizzo  Dipendente       Advocacy Nazionale
# 104   Federica  Salvatore  Dipendente  Advocacy Internazionale
# 105      Greta      Testa  Dipendente  Advocacy Internazionale
# 106  Salvatore      Monti  Dipendente       Advocacy Nazionale
#
#                          Area  \
# 2                  Educazione
# 3                     Private
# 4    Migrazione & Accoglienza
# 5                       Clima
# 6                     Povertà
# ..                        ...
# 102                   Povertà
# 103                    Salute
# 104          Crisi Umanitarie
# 105          Crisi Umanitarie
# 106                   Povertà
#
#                                             Tematica    Data Inizio Ruolo  \
# 2                             Dispersione Scolastica  2020-12-17 00:00:00
# 3                                        Agenda 2030  2018-04-17 00:00:00
# 4                                         Inclusione  2019-05-20 00:00:00
# 5                                    Generation Hope  2024-12-17 00:00:00
# 6           Supporto a Famiglie Vittime di Emergenze  2018-04-15 00:00:00
# ..                                               ...                  ...
# 102               Reddito di Inclusione/Cittadinanza           2021/04/25
# 103  Supporto a Minori Vittime di Violenza Assistita           2021/09/20
# 104                                             Armi           2019/09/18
# 105                                 Aree Geografiche           2021/07/19
# 106         Supporto a Famiglie Vittime di Emergenze           2023/10/09
#
#     Data Fine Ruolo
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# ..              ...
# 102             NaN
# 103             NaN
# 104             NaN
# 105             NaN
# 106             NaN
#
# [105 rows x 8 columns]

# %%
# Aggiungo il campo Tematica
lista_tematiche = Anagrafiche['Tematica'].unique().tolist()
lista_tematiche
# Out:
# ['Dispersione Scolastica',
#  'Agenda 2030',
#  'Inclusione',
#  'Generation Hope',
#  'Supporto a Famiglie Vittime di Emergenze',
#  'Fame',
#  'Mense Scolastiche',
#  'Human Rights and Business',
#  'Piano Mattei',
#  'Supporto a Minori Vittime di Violenza Assistita',
#  'Education Cannot Wait',
#  'Child Labour Policy',
#  'Periferie',
#  'Accountability',
#  'Patto Asilo Migrazione',
#  'Safe School Declaration',
#  'Supporto alla Genitorialità',
#  'Global Partnership for Education',
#  'Criminalità Minorile',
#  'Lavoro di Cura',
#  'Processo COP',
#  'Bullismo',
#  'Children and Armed Conflict',
#  'Minori Stranieri non Accompagnati',
#  'Aree Geografiche',
#  'Financing for Development',
#  'Armi',
#  'Quartieri d’Innovazione',
#  'Partecipazione Giovanile',
#  'Cittadinanza',
#  'Povertà Educativa',
#  'Reddito di Inclusione/Cittadinanza']

# %%
tematiche_casuali = random.choices(lista_tematiche, k=494)
sampled_df['Tematica'] = tematiche_casuali

# %%
sampled_df
# Out:
#              Istituzione                                          Direzione  \
# 227  Parlamento Italiano                            Senato della Repubblica
# 298  Parlamento Italiano                                Camera dei Deputati
# 195  Parlamento Italiano                                Camera dei Deputati
# 167  Parlamento Italiano                            Senato della Repubblica
# 406     Governo Italiano  Ministero per la famiglia la natalit├á e le pa...
# ..                   ...                                                ...
# 210  Parlamento Italiano                            Senato della Repubblica
# 267  Parlamento Italiano                                Camera dei Deputati
# 62    Parlamento Europeo                               Parlamentare Europeo
# 154  Parlamento Italiano                                Camera dei Deputati
# 174  Parlamento Italiano                                Camera dei Deputati
#
#                                                Ufficio  \
# 227                             Affari esteri e difesa
# 298                      Politiche Dell'Unione Europea
# 195         Commissione Permanente Difesa della Camera
# 167                             Affari esteri e difesa
# 406  Ministro senza portafoglio per la famiglia la ...
# ..                                                 ...
# 210                      Politiche dell'Unione europea
# 267              Ambiente Territorio E Lavori Pubblici
# 62                                              Italia
# 154                         Affari Esteri E Comunitari
# 174                          Lavoro Pubblico E Privato
#
#                   Riferimento Data_Incontro Modalita_Incontro  Info  \
# 227           SPAGNOLLI Luigi    2022-01-07            Online  None
# 298   GIGLIO VIGNA Alessandro    2022-01-11            Online  None
# 195             FASSINO Piero    2022-01-12            Online  None
# 167    CASINI Pier Ferdinando    2022-01-14           De Visu  None
# 406    ROCCELLA Eugenia Maria    2022-01-19            Online  None
# ..                        ...           ...               ...   ...
# 210              RENZI Matteo    2024-05-06            Online  None
# 267            L'ABBATE Patty    2024-05-07           De Visu  None
# 62         Alessandra MORETTI    2024-05-08            Online  None
# 154  QUARTAPELLE PROCOPIO Lia    2024-05-11           De Visu  None
# 174           GIACCONE Andrea    2024-05-16           De Visu  None
#
#      Id_Valutazione  ID_Incontro                          Tematica
# 227               3            1             Education Cannot Wait
# 298               3            2                      Cittadinanza
# 195               1            3                         Periferie
# 167               2            4                         Periferie
# 406               2            5       Supporto alla Genitorialità
# ..              ...          ...                               ...
# 210               4          490                   Generation Hope
# 267               4          491  Global Partnership for Education
# 62                3          492                      Piano Mattei
# 154               2          493       Children and Armed Conflict
# 174               3          494       Children and Armed Conflict
#
# [494 rows x 10 columns]

# %%
#Aggiungo il campo Promotore
nome_promotore = []
cognome_promotore = []

# %%
for index, row in sampled_df.iterrows():
    tematica_corrente = row['Tematica']
    records_con_tematica = Anagrafiche[Anagrafiche['Tematica'] == tematica_corrente]
    record_scelto = random.choice(records_con_tematica.to_dict('records'))
    nome_promotore.append(record_scelto['Nome'])
    cognome_promotore.append(record_scelto['Cognome'])
    
sampled_df['Nome Promotore'] = nome_promotore
sampled_df['Cognome Promotore'] = cognome_promotore

sampled_df
# Out:
#              Istituzione                                          Direzione  \
# 227  Parlamento Italiano                            Senato della Repubblica
# 298  Parlamento Italiano                                Camera dei Deputati
# 195  Parlamento Italiano                                Camera dei Deputati
# 167  Parlamento Italiano                            Senato della Repubblica
# 406     Governo Italiano  Ministero per la famiglia la natalit├á e le pa...
# ..                   ...                                                ...
# 210  Parlamento Italiano                            Senato della Repubblica
# 267  Parlamento Italiano                                Camera dei Deputati
# 62    Parlamento Europeo                               Parlamentare Europeo
# 154  Parlamento Italiano                                Camera dei Deputati
# 174  Parlamento Italiano                                Camera dei Deputati
#
#                                                Ufficio  \
# 227                             Affari esteri e difesa
# 298                      Politiche Dell'Unione Europea
# 195         Commissione Permanente Difesa della Camera
# 167                             Affari esteri e difesa
# 406  Ministro senza portafoglio per la famiglia la ...
# ..                                                 ...
# 210                      Politiche dell'Unione europea
# 267              Ambiente Territorio E Lavori Pubblici
# 62                                              Italia
# 154                         Affari Esteri E Comunitari
# 174                          Lavoro Pubblico E Privato
#
#                   Riferimento Data_Incontro Modalita_Incontro  Info  \
# 227           SPAGNOLLI Luigi    2022-01-07            Online  None
# 298   GIGLIO VIGNA Alessandro    2022-01-11            Online  None
# 195             FASSINO Piero    2022-01-12            Online  None
# 167    CASINI Pier Ferdinando    2022-01-14           De Visu  None
# 406    ROCCELLA Eugenia Maria    2022-01-19            Online  None
# ..                        ...           ...               ...   ...
# 210              RENZI Matteo    2024-05-06            Online  None
# 267            L'ABBATE Patty    2024-05-07           De Visu  None
# 62         Alessandra MORETTI    2024-05-08            Online  None
# 154  QUARTAPELLE PROCOPIO Lia    2024-05-11           De Visu  None
# 174           GIACCONE Andrea    2024-05-16           De Visu  None
#
#      Id_Valutazione  ID_Incontro                          Tematica  \
# 227               3            1             Education Cannot Wait
# 298               3            2                      Cittadinanza
# 195               1            3                         Periferie
# 167               2            4                         Periferie
# 406               2            5       Supporto alla Genitorialità
# ..              ...          ...                               ...
# 210               4          490                   Generation Hope
# 267               4          491  Global Partnership for Education
# 62                3          492                      Piano Mattei
# 154               2          493       Children and Armed Conflict
# 174               3          494       Children and Armed Conflict
#
#     Nome Promotore Cognome Promotore
# 227           Nina          Cattaneo
# 298         Mattia            Marini
# 195       Riccardo              Neri
# 167         Andrea           Colombo
# 406          Rocco             Testa
# ..             ...               ...
# 210           Sara          Barbieri
# 267         Miriam             Conte
# 62         Matilde        De Angelis
# 154          Sofia            Vitale
# 174         Serena           De Rosa
#
# [494 rows x 12 columns]

# %%
#Aggiungo il campo Accompagnatore, tenendo conto che la risorsa lavori nella stessa Tematica del promotore
nome_accompagnatore = []
cognome_accompagnatore = []

for index, row in sampled_df.iterrows():
    tematica_corrente = row['Tematica']
    records_con_tematica = Anagrafiche[Anagrafiche['Tematica'] == tematica_corrente]
    record_scelto = random.choice(records_con_tematica.to_dict('records'))
    nome_accompagnatore.append(record_scelto['Nome'])
    cognome_accompagnatore.append(record_scelto['Cognome'])
    
sampled_df['Nome Accompagnatore'] = nome_accompagnatore
sampled_df['Cognome Accompagnatore'] = cognome_accompagnatore

sampled_df
# Out:
#              Istituzione                                          Direzione  \
# 227  Parlamento Italiano                            Senato della Repubblica
# 298  Parlamento Italiano                                Camera dei Deputati
# 195  Parlamento Italiano                                Camera dei Deputati
# 167  Parlamento Italiano                            Senato della Repubblica
# 406     Governo Italiano  Ministero per la famiglia la natalit├á e le pa...
# ..                   ...                                                ...
# 210  Parlamento Italiano                            Senato della Repubblica
# 267  Parlamento Italiano                                Camera dei Deputati
# 62    Parlamento Europeo                               Parlamentare Europeo
# 154  Parlamento Italiano                                Camera dei Deputati
# 174  Parlamento Italiano                                Camera dei Deputati
#
#                                                Ufficio  \
# 227                             Affari esteri e difesa
# 298                      Politiche Dell'Unione Europea
# 195         Commissione Permanente Difesa della Camera
# 167                             Affari esteri e difesa
# 406  Ministro senza portafoglio per la famiglia la ...
# ..                                                 ...
# 210                      Politiche dell'Unione europea
# 267              Ambiente Territorio E Lavori Pubblici
# 62                                              Italia
# 154                         Affari Esteri E Comunitari
# 174                          Lavoro Pubblico E Privato
#
#                   Riferimento Data_Incontro Modalita_Incontro  Info  \
# 227           SPAGNOLLI Luigi    2022-01-07            Online  None
# 298   GIGLIO VIGNA Alessandro    2022-01-11            Online  None
# 195             FASSINO Piero    2022-01-12            Online  None
# 167    CASINI Pier Ferdinando    2022-01-14           De Visu  None
# 406    ROCCELLA Eugenia Maria    2022-01-19            Online  None
# ..                        ...           ...               ...   ...
# 210              RENZI Matteo    2024-05-06            Online  None
# 267            L'ABBATE Patty    2024-05-07           De Visu  None
# 62         Alessandra MORETTI    2024-05-08            Online  None
# 154  QUARTAPELLE PROCOPIO Lia    2024-05-11           De Visu  None
# 174           GIACCONE Andrea    2024-05-16           De Visu  None
#
#      Id_Valutazione  ID_Incontro                          Tematica  \
# 227               3            1             Education Cannot Wait
# 298               3            2                      Cittadinanza
# 195               1            3                         Periferie
# 167               2            4                         Periferie
# 406               2            5       Supporto alla Genitorialità
# ..              ...          ...                               ...
# 210               4          490                   Generation Hope
# 267               4          491  Global Partnership for Education
# 62                3          492                      Piano Mattei
# 154               2          493       Children and Armed Conflict
# 174               3          494       Children and Armed Conflict
#
#     Nome Promotore Cognome Promotore Nome Accompagnatore  \
# 227           Nina          Cattaneo             Roberto
# 298         Mattia            Marini              Pietro
# 195       Riccardo              Neri              Andrea
# 167         Andrea           Colombo              Andrea
# 406          Rocco             Testa               Rocco
# ..             ...               ...                 ...
# 210           Sara          Barbieri                Sara
# 267         Miriam             Conte              Nicolò
# 62         Matilde        De Angelis            Federica
# 154          Sofia            Vitale              Serena
# 174         Serena           De Rosa              Serena
#
#     Cognome Accompagnatore
# 227               Barbieri
# 298                  Gallo
# 195                Colombo
# 167                Colombo
# 406                  Testa
# ..                     ...
# 210               Barbieri
# 267                   Neri
# 62               Salvatore
# 154                De Rosa
# 174                De Rosa
#
# [494 rows x 14 columns]

# %%
# Importo il file delle KPI e pulisco i dati
KPI_link = "kpi_tem.csv"
KPI = pd.read_csv(KPI_link)

# %%
print(KPI.columns)
# Out:
# Index(['ID_KPI_Tematica', ' Nome KPI Tematica', ' Tematica'], dtype='object')

# %%
KPI[' Tematica'] = KPI[' Tematica'].replace('Povert├á Educativa', 'Povertà Educativa')
KPI[' Tematica'] = KPI[' Tematica'].replace('Criminalit├á Minorile', 'Criminalitá Minorile')
KPI[' Tematica'] = KPI[' Tematica'].replace('Supporto alla Genitorialit├á', 'Supporto alla Genitorialitá')
KPI[' Tematica'] = KPI[' Tematica'].replace('Quartieri dÔÇÖInnovazione', 'Quartieri d"Innovazione')

# %%
KPI.rename(columns={' Tematica': 'Tematica'}, inplace=True)

# %%
KPI.rename(columns={' Nome KPI Tematica': 'Nome KPI Tematica'}, inplace=True)

# %%
# Assegnazione randomica KPI Tematica
import numpy as np

lista_KPI = []

for index, row in sampled_df.iterrows():
    tematica_corrente = row['Tematica']
    records_con_tematica = KPI[KPI['Tematica'] == tematica_corrente]
    
    if not records_con_tematica.empty:
        record_scelto = random.choice(records_con_tematica.to_dict('records'))
        lista_KPI.append(record_scelto['Nome KPI Tematica'])
    else:
        lista_KPI.append(np.nan)  # Aggiungi un valore nullo se non ci sono record disponibili

sampled_df['KPI Tematica'] = lista_KPI

sampled_df
# Out:
#              Istituzione                                          Direzione  \
# 227  Parlamento Italiano                            Senato della Repubblica
# 298  Parlamento Italiano                                Camera dei Deputati
# 195  Parlamento Italiano                                Camera dei Deputati
# 167  Parlamento Italiano                            Senato della Repubblica
# 406     Governo Italiano  Ministero per la famiglia la natalit├á e le pa...
# ..                   ...                                                ...
# 210  Parlamento Italiano                            Senato della Repubblica
# 267  Parlamento Italiano                                Camera dei Deputati
# 62    Parlamento Europeo                               Parlamentare Europeo
# 154  Parlamento Italiano                                Camera dei Deputati
# 174  Parlamento Italiano                                Camera dei Deputati
#
#                                                Ufficio  \
# 227                             Affari esteri e difesa
# 298                      Politiche Dell'Unione Europea
# 195         Commissione Permanente Difesa della Camera
# 167                             Affari esteri e difesa
# 406  Ministro senza portafoglio per la famiglia la ...
# ..                                                 ...
# 210                      Politiche dell'Unione europea
# 267              Ambiente Territorio E Lavori Pubblici
# 62                                              Italia
# 154                         Affari Esteri E Comunitari
# 174                          Lavoro Pubblico E Privato
#
#                   Riferimento Data_Incontro Modalita_Incontro  Info  \
# 227           SPAGNOLLI Luigi    2022-01-07            Online  None
# 298   GIGLIO VIGNA Alessandro    2022-01-11            Online  None
# 195             FASSINO Piero    2022-01-12            Online  None
# 167    CASINI Pier Ferdinando    2022-01-14           De Visu  None
# 406    ROCCELLA Eugenia Maria    2022-01-19            Online  None
# ..                        ...           ...               ...   ...
# 210              RENZI Matteo    2024-05-06            Online  None
# 267            L'ABBATE Patty    2024-05-07           De Visu  None
# 62         Alessandra MORETTI    2024-05-08            Online  None
# 154  QUARTAPELLE PROCOPIO Lia    2024-05-11           De Visu  None
# 174           GIACCONE Andrea    2024-05-16           De Visu  None
#
#      Id_Valutazione  ID_Incontro                          Tematica  \
# 227               3            1             Education Cannot Wait
# 298               3            2                      Cittadinanza
# 195               1            3                         Periferie
# 167               2            4                         Periferie
# 406               2            5       Supporto alla Genitorialità
# ..              ...          ...                               ...
# 210               4          490                   Generation Hope
# 267               4          491  Global Partnership for Education
# 62                3          492                      Piano Mattei
# 154               2          493       Children and Armed Conflict
# 174               3          494       Children and Armed Conflict
#
#     Nome Promotore Cognome Promotore Nome Accompagnatore  \
# 227           Nina          Cattaneo             Roberto
# 298         Mattia            Marini              Pietro
# 195       Riccardo              Neri              Andrea
# 167         Andrea           Colombo              Andrea
# 406          Rocco             Testa               Rocco
# ..             ...               ...                 ...
# 210           Sara          Barbieri                Sara
# 267         Miriam             Conte              Nicolò
# 62         Matilde        De Angelis            Federica
# 154          Sofia            Vitale              Serena
# 174         Serena           De Rosa              Serena
#
#     Cognome Accompagnatore                                       KPI Tematica
# 227               Barbieri                Allocazione fondi addizionali a ECW
# 298                  Gallo           Legge su cittadinanza a minori stranieri
# 195                Colombo   Miglioramento fruizione dei servizi in periferia
# 167                Colombo   Miglioramento fruizione dei servizi in periferia
# 406                  Testa                                                NaN
# ..                     ...                                                ...
# 210               Barbieri  Aumento delle attività di piazza con partecipa...
# 267                   Neri                     Rilancio supporto al fondo GPE
# 62               Salvatore                            Allocazione fondi a ONG
# 154                De Rosa  Strutturazione di sistemi di monitoraggio capi...
# 174                De Rosa  Strutturazione di sistemi di monitoraggio capi...
#
# [494 rows x 15 columns]

# %%
nuovo_ordine = ['ID_Incontro', 'Nome Promotore', 'Cognome Promotore', 'Nome Accompagnatore', 'Cognome Accompagnatore', 'Data_Incontro', 'Modalita_Incontro', 'Istituzione', 'Direzione', 'Ufficio',
                'Riferimento', 'Tematica', 'KPI Tematica', 'Id_Valutazione', 'Info']
sampled_df = sampled_df.reindex(columns=nuovo_ordine)

# %%
sampled_df.to_csv('sampled.csv', index=False)
